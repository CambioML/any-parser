# %% [markdown]
# ## Async Anyparser Pro Endpoint for Multi-Language Support

# %%
# Install the libraries (ipython is used for displaying markdown in this demo)
# !pip3 install --upgrade ipython
# !pip3 install --upgrade any-parser

# %%
from IPython.display import display, Markdown, Image
from any_parser import AnyParser
import os
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
example_apikey = os.getenv("CAMBIO_API_KEY")

# %%
# Display the image
display(Image("./sample_data/sample_arabic_1.png"))

# %%
ap = AnyParser(example_apikey)


file_id = ap.async_parse_pro(file_path="./sample_data/sample_arabic_1.png")

# %%
markdown_output = ap.async_fetch(file_id=file_id)
# Out:
# Waiting for response...
# Waiting for response...
# Waiting for response...

# %%
display(Markdown(markdown_output))
# Out:
# النزاع
# أ.٢١ / لبنان ٢٠١٨-٢٠٢١/الأزمة السورية
# الشرق الأوسط
# السيا ق
# بعد مرور عشر سنوات على الأزمة السورية، يستضيف لبنانٍ أكبر عدد من اللاجئين في العالم على أساس نصيب الفرد. وقد أصيب الاقتصاد اللبناني بالشلل في عام ٢٠٢٠ بسبب الأزمة الاقتصادية ووباء كوفيد-١٩ وانفجار بيروت عام ٢٠٢٠. وقبل الأزمة الاقتصادية، كان الاقتصاد الوظيفي وقدرة القوى العاملة السورية على العمل الزراعي والصناعي تسهّل تخفيف حدة التوترات الاجتماعية. والآن تتزايد التوترات الطائفية والسياسية، حيث غالبا ما يلام اللاجئون السوريون على المساهمة في الانهيار الاقتصادي للبلاد ويُعتَبَرون منافسين على الوظائف والموارد.
# الظروف المعيشية
# ...
